# %% [markdown]
# #  3D Chart

# %% [markdown]
# # Import Module

# %% [markdown]
# # magic command

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # membuat 3D axes

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 3D line plot

# %%
z = np.linspace(0,1,100)
x = z * np.sin(20 * z)
y = z * np.cos(20 * z)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot(x,y,z,c='r')
ax.set(xlabel='Sumbu X',ylabel='Sumbu Y',zlabel='Sumbu Z',title='Contoh 3D line plot')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 3D Scatter plot

# %%
z = np.linspace(0,1,100)
x = z * np.sin(20 * z)
y = z * np.cos(20 * z)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.scatter(x,y,z,c='y')
ax.set(xlabel='Sumbu X',ylabel='Sumbu Y',zlabel='Sumbu Z',title='3D Scatter Plot')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
