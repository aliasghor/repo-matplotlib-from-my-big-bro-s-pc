# %% [markdown]
# # 3D Area Chart

# %% [markdown]
# # magic command

# %%
# %matplotlib notebook

# %% [markdown]
# # import modules

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.7.0
# 1.23.5

# %% [markdown]
# # sample dataset

# %%
n = np.linspace(-3.0,3.0,100)
x, y = np.meshgrid(n,n)
z = np.sqrt(x**2 + y**2)
print(x.shape)
print(y.shape)
print(z.shape)
# Out:
# (100, 100)
# (100, 100)
# (100, 100)

# %% [markdown]
# # 3D Wireframe

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_wireframe(x,y,z,color='orange')
ax.set(xlabel='Sumbu X',ylabel='Sumbu Y',zlabel='Sumbu Z',title='3D Wireframe')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %% [markdown]
# # 3D Surface Plot

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x,y,z,cmap='viridis')
ax.set(xlabel='Sumbu X',ylabel='+Sumbu Y',zlabel='Sumbu Z',title='3D Surface Plot')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
