# %% [markdown]
# # Twin Axes

# %% [markdown]
# # magic command

# %%
# %matplotlib inline

# %% [markdown]
# # import module

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # dataset

# %%
x = np.linspace(1,10,25)
x
# Out:
# array([ 1.   ,  1.375,  1.75 ,  2.125,  2.5  ,  2.875,  3.25 ,  3.625,
#         4.   ,  4.375,  4.75 ,  5.125,  5.5  ,  5.875,  6.25 ,  6.625,
#         7.   ,  7.375,  7.75 ,  8.125,  8.5  ,  8.875,  9.25 ,  9.625,
#        10.   ])

# %% [markdown]
# # twin axes example

# %%
fig, ax1 = plt.subplots()

ax1.plot(x,np.exp(x),'bs-',label='exponent')
ax1.set_label('x axis')
ax1.set_ylabel('exponent')

ax2 = ax1.twinx()

ax2.plot(x,np.log(x),'r^-',label='log')
ax2.set_ylabel('log')

fig.suptitle('twin axes example')
fig.legend(loc='upper left')

plt.show()

# %% [markdown]
# # another twin axes example

# %%
x = np.random.randint(16,40,size=30)
x
# Out:
# array([22, 25, 36, 26, 19, 21, 19, 33, 38, 27, 34, 35, 17, 29, 20, 36, 30,
#        38, 28, 37, 39, 16, 29, 37, 33, 21, 31, 37, 26, 20])

# %%
def C2F(celcius=0):
    return (celcius * 1.8) + 32

def konversi_sumbu(ax1):
    y1, y2 = ax1.get_ylim()
    ax2.set_ylim(C2F(y1),C2F(y2))
    ax2.figure.canvas.draw()
    
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.callbacks.connect('ylim_changed',konversi_sumbu)
ax1.plot(x)

ax1.set_xlabel('hari')
ax1.set_ylabel('celcius')
ax2.set_ylabel('fahrenheit')

fig.suptitle('temperatur udara')
plt.show()
